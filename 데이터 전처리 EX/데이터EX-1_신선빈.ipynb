# %% [markdown]
# # 데이터 전처리 EX-1

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
import matplotlib.pyplot as plt

#list에 값 저장
titanic_list = []

#Age = 평균값(mean), Embarked = 최빈값(mode), Cabin = drop
df = pd.read_csv('train.csv')

#Age = 평균값
df['Age'] = df['Age'].fillna(df['Age'].mean())

#Embarked = 최빈값
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

#Cabin = drop(열)
cabin_drop_columns = df.drop('Cabin', axis=1)
cabin_drop_columns1 = cabin_drop_columns.isnull().sum()

# %%
print(cabin_drop_columns1)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
