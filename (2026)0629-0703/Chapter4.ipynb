# %% [markdown]
# # 기초통계

# %%
#pandas를 이용 => 평균, 중앙, 최빈값
#mean, median, mode
import pandas as pd

# %%
data = [10, 15, 10, 20, 30, 10, 40]

data_series = pd.Series(data)

# %%
#평균
mean_val = data_series.mean()
#중앙값
median_val = data_series.median()
#최빈값(만약 그 중 첫번째 값을 알고 싶다면 mode()[0]을 붙이면 된다)
mode_val = data_series.mode()[0]

# %%
print(mean_val)
print(median_val)
print(mode_val)
# Out:
# 19.285714285714285
# 15.0
# 10

# %% [markdown]
# # 데이터 분산성(분산, 표준편차, 사분위수)

# %%
data = {'점수': [55, 60, 65, 70, 75, 80, 85, 90, 95]}

df = pd.DataFrame(data)

# %%
#분산 - var
var_value = df['점수'].var()
print(var_value)
# Out:
# 187.5

# %%
#표준편차 - std
std_value = df['점수'].std()
print(std_value)
# Out:
# 13.693063937629153

# %%
#사분위수
q1_value_pd = df['점수'].quantile(0.25) #1사분위수
q2_value_pd = df['점수'].quantile(0.5) #2사분위수
q3_value_pd = df['점수'].quantile(0.75) #3사분위수
q4_value_pd = df['점수'].max() #최대값

print(q1_value_pd)
print(q2_value_pd)
print(q3_value_pd)
print(q4_value_pd)

#IQR (Q3-Q1)
iqr_value = q3_value_pd - q1_value_pd
print(iqr_value)
# Out:
# 65.0
# 75.0
# 85.0
# 95
# 20.0

# %% [markdown]
# # 데이터 시각화(matplotlib, seaborn)

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (3.11.0)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: six>=1.5 in /Users/shinsunbin/Documents/GitHub/shieldus_education/.venv-1/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
