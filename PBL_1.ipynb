# %% [markdown]
# ### PBL 실습1

# %%
#필요 library 다운로드
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-3.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv-1/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv-1/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.3-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
# Downloading numpy-2.5.0-cp312-cp312-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 8.3 MB/s  0:00:00 eta 0:00:01m
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.5.0 pandas-3.0.3

# %%
import os
import re
import pandas as pd

#1. 파일이 있는지 check
file_path = ('/Users/shinsunbin/Documents/GitHub/shieldus_education/log_file/sample_log_file.log')
os.path.exists(file_path) #1-1. 있다면 True / 없다면 False

#2. 파일 출력해보기
pd.read_csv(file_path)
# Out:
#    10.0.0.1 - user2 [12/Jun/2025:09:00:00 +0900] "GET /data HTTP/1.1" 200 1875
# 0   203.0.113.10 - hacker [12/Jun/2025:09:00:05 +0...
# 1   172.16.0.2 - user3 [12/Jun/2025:09:00:10 +0900...
# 2   203.0.113.10 - user2 [12/Jun/2025:09:00:15 +09...
# 3   203.0.113.5 - user1 [12/Jun/2025:09:00:20 +090...
# 4   203.0.113.10 - hacker [12/Jun/2025:09:00:25 +0...
# ..                                                ...
# 94  10.0.0.1 - user2 [12/Jun/2025:09:07:55 +0900] ...
# 95  127.0.0.1 - user1 [12/Jun/2025:09:08:00 +0900]...
# 96  198.51.100.23 - user1 [12/Jun/2025:09:08:05 +0...
# 97  172.16.0.2 - user2 [12/Jun/2025:09:08:10 +0900...
# 98  192.168.0.3 - user2 [12/Jun/2025:09:08:15 +090...
#
# [99 rows x 1 columns]
